# %%
# ClaSP example code for time series segmentation

# %%
# First we should install claspy
# !pip3 install claspy
# Out:
# Collecting claspy
#   Downloading claspy-0.2.5-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy<2.1.0,>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from claspy) (1.26.4)
# Requirement already satisfied: numba>=0.53 in /usr/local/lib/python3.11/dist-packages (from claspy) (0.61.0)
# Requirement already satisfied: pandas<2.3.0,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from claspy) (2.2.2)
# Collecting scikit-learn<1.6.0,>=0.24.0 (from claspy)
#   Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: scipy<2.0.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from claspy) (1.13.1)
# Requirement already satisfied: statsmodels>=0.13.5 in /usr/local/lib/python3.11/dist-packages (from claspy) (0.14.4)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.11/dist-packages (from claspy) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->claspy) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->claspy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->claspy) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->claspy) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->claspy) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->claspy) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->claspy) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3->claspy) (2.8.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.53->claspy) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0,>=1.1.0->claspy) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3.0,>=1.1.0->claspy) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<1.6.0,>=0.24.0->claspy) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<1.6.0,>=0.24.0->claspy) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels>=0.13.5->claspy) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->claspy) (1.17.0)
# Downloading claspy-0.2.5-py3-none-any.whl (36 kB)
# Downloading scikit_learn-1.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 48.2 MB/s eta 0:00:00
# Installing collected packages: scikit-learn, claspy
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# Successfully installed claspy-0.2.5 scikit-learn-1.5.2

# %%
from claspy.segmentation import BinaryClaSPSegmentation
from claspy.data_loader import load_tssb_dataset
import matplotlib.pyplot as plt

# %%
# Load CricketX dataset for segmentation
dataset, window_size, true_cps, time_series = load_tssb_dataset(names=("CricketX",)).iloc[0,:]
plt.figure(figsize=(12, 3))
plt.plot(time_series)

# %%
# Segment with ClaSP (it may take ~30 seconds)
clasp = BinaryClaSPSegmentation()
clasp.fit_predict(time_series)
# Out:
# array([ 712, 1281, 1933, 2581])

# %%
# Plot segmentation results
clasp.plot(gt_cps=true_cps, heading="Segmentation of different umpire cricket signals", ts_name="ACC", file_path="segmentation_example.png")
# Out:
# array([<Axes: title={'center': 'Segmentation of different umpire cricket signals'}, ylabel='ACC'>,
#        <Axes: xlabel='split point', ylabel='ClaSP Score'>], dtype=object)
